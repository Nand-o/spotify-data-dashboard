# %% [markdown]
# <a href="https://colab.research.google.com/github/Nand-o/spotify-data-dashboard/blob/ferris/dataset_spotify_tracks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q streamlit

# %%
# %%writefile app.py
import streamlit as st

x = st.slider('Select a value')
st.write(x, 'squared is', x * x)

# %%
# !npm install localtunnel

# %%
# !streamlit run /content/app.py &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501
